# %% [markdown]
# # Python TASK
#
# You have to write a python script which can fetch all the tweets(as many as allowed by Twitter
# API) done by midas@IIITD twitter handle and dump the responses into JSONlines file.
# The other part of your script should be able to parse these JSONline files to display the
# following for every tweet in a tabular format.
# 1. The text of the tweet.
# 2. Date and time of the tweet.
# 3. The number of favorites/likes.
# 4. The number of retweets.
# 5. Number of Images present in Tweet. If no image returns None.
#
# ### Submitted by
# #### Utkarsh Sharma (flamingice2801@gmail.com)

# %% [markdown]
# ## 1. Dowload Data from Twitter API

# %%
#Load Libraries
import keys
import requests
from requests_oauthlib import OAuth1
import json

#Define Authorization to authorize the Twitter API use
auth = OAuth1(keys.api_key, keys.api_secret_key, keys.access_token, keys.access_token_secret)

#Function to json dump the data on to the disk
def dump_json(data, filename):
    with open(filename, 'w') as outfile:
        json.dump(data, outfile)
    print("Successfully saved data")

#Function to download data from Twitter
def request_data(url_req, params, auth):
    data = []
    fromDate = None
    toDate = None
    
    while True:
        #Get response from Twitter API
        results = requests.get(url_rest, params=params, auth=auth)
        is_response_ok = results.ok
        if is_response_ok:
            #Get the results in a json format
            results = results.json()
            
            #Append the results together in a list
            data = data + results['results']
            
            #If the response has next key, then continue downloading more data else break the loop
            if 'next' in results.keys():
                params['next'] = results['next']
            else:
                fromDate = results['requestParameters']['fromDate']
                toDate = results['requestParameters']['toDate']
                break

    return {'results':data, 'requestParameters':{'fromDate':fromDate, 'toDate':toDate}}

if __name__ == '__main__':
    
    #URL for search reques. The api used is twitter premium search api
    url_rest = "https://api.twitter.com/1.1/tweets/search/fullarchive/test.json"
    
    #Query contains the twitter handle of MIDAS IIITD
    query = 'from:midasIIITD'
    
    #fromDate parameter is the date from which the tweets are downloaded to the current date
    #The follwing date is September 1, 2018. That means tweets will be downloaded from Sept 1, 2018 to Mar 26, 2019
    fromDate = 201809010000
    
    #Define a dictionary for all parameters
    params = {'query': query, 'maxResults':100, 'next':None, 'fromDate':fromDate}
    
    #Request data from Twitter API
    data = request_data(url_rest, params, auth)
    
    #Dump the data in data.json file
    out_filename = 'data.json'
    dump_json(data, out_filename)
# Out:
# Successfully saved data

# %% [markdown]
# ## Load JSON file from disk and parse it to extract the required information

# %%
#Load libraries
import json
from collections import defaultdict
import pandas as pd
from texttable import Texttable

#Function to load the json file from disk
def load_json(filename):
    with open(filename, 'r') as infile:
        data = json.load(infile)
    return data

#Function to extract number of images from a tweet
def get_num_images(tweet_data):
    num_images = 0
    
    #Find the number of images from the tweet. If any media is present in the tweet, the Twitter API have its details in the entities key
    #Count the number of media whose type is photo
    if 'extended_tweet' in tweet_data.keys() and 'entities' in tweet_data['extended_tweet'].keys() and 'media' in tweet_data['extended_tweet']['entities'].keys():
        count = 0
        for med in tweet_data['extended_tweet']['entities']['media']:
            if med['type'] == 'photo':
                count = count+1
        num_images = count
    
    if 'entities' in tweet_data.keys() and 'media' in tweet_data['entities'].keys():
        count = 0
        for med in tweet_data['entities']['media']:
            if med['type'] == 'photo':
                count = count+1
        num_images = count
    
    #If num_images is 0 then return None else return num_images
    if num_images != 0:
        return num_images
    else:
        return None

#Function to parse the json file    
def parse_json(filename):
    data = load_json(filename)
    
    #Define a dictioary with keys and values as list
    data_dict = defaultdict(list)
    
    #Loop over every tweet in the loaded json file
    for i, tweet_data in enumerate(data['results']):
        
        #Extract the required information.
        #If the tweet has retweeted_status key then change the tweet to retweeted_status
        if 'retweeted_status' in tweet_data.keys():
            tweet_data = tweet_data['retweeted_status']
            
        #If the tweet_data has extended_tweet key then extract the full tweet text from it
        if 'extended_tweet' in tweet_data.keys():
            text = tweet_data['extended_tweet']['full_text']
        else:
            text = tweet_data['text']
        
        #Get the number of images present in a tweet
        num_images = get_num_images(tweet_data)
        
        #Get the date and time of the tweet
        date_time = tweet_data['created_at']
        
        #Get the number of likes/favorites
        favorite_count = tweet_data['favorite_count']
        
        #Get the number of retweets
        retweet_count = tweet_data['retweet_count']
        
        #Append the extracted information in the data_dict
        data_dict['text'].append(text)
        data_dict['date_time'].append(date_time)
        data_dict['num_favorites'].append(favorite_count)
        data_dict['num_retweets'].append(retweet_count)
        data_dict['num_images'].append(num_images)
    return data_dict

#Function to draw table from extracted data
def draw_table(data_dict):
    table = Texttable()
    #Add column names
    table.header(data_dict.keys())
    #Iteratively add each row
    for i in range(len(data_dict['text'])):
        table.add_row([data_dict['text'][i], data_dict['date_time'][i], data_dict['num_favorites'][i], data_dict['num_retweets'][i], data_dict['num_images'][i]])
    print(table.draw())

if __name__ == '__main__':
    
    filename = 'data.json'
    
    #Extract required information from json file and save it in a dictionary
    data_dict = parse_json(filename)
    
    #Draw table
    draw_table(data_dict)
    
#     print(pd.DataFrame(data_dict, dtype='int32'))
# Out:
# +-----------------+----------------+---------------+--------------+------------+
# |      text       |   date_time    | num_favorites | num_retweets | num_images |
# +=================+================+===============+==============+============+
# | Congratulations | Mon Mar 25     | 8             | 1            | 2          |
# | @midasIIITD     | 13:01:57 +0000 |               |              |            |
# | students Simra  | 2019           |               |              |            |
# | Shahid @Simcyy  |                |               |              |            |
# | and Nilay       |                |               |              |            |
# | Shrivastava     |                |               |              |            |
# | @NilayShri on   |                |               |              |            |
# | getting         |                |               |              |            |
# | selected for a  |                |               |              |            |
# | research        |                |               |              |            |
# | internship at   |                |               |              |            |
# | Adobe in this   |                |               |              |            |
# | summer.         |                |               |              |            |
# |                 |                |               |              |            |
# | #MIDAS          |                |               |              |            |
# | #Achievment     |                |               |              |            |
# | #Research       |                |               |              |            |
# | #Summer         |                |               |              |            |
# | #Internship htt |                |               |              |            |
# | ps://t.co/WdF66 |                |               |              |            |
# | 3EB5y           |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | The last date   | Sun Mar 24     | 8             | 3            | None       |
# | for submitting  | 18:44:01 +0000 |               |              |            |
# | a solution for  | 2019           |               |              |            |
# | the @midasIIITD |                |               |              |            |
# | internship task |                |               |              |            |
# | is 26th March   |                |               |              |            |
# | midnight. We    |                |               |              |            |
# | will not accept |                |               |              |            |
# | solutions       |                |               |              |            |
# | submitted after |                |               |              |            |
# | the deadline.   |                |               |              |            |
# | Thus, if you    |                |               |              |            |
# | have not        |                |               |              |            |
# | submitted your  |                |               |              |            |
# | solution yet    |                |               |              |            |
# | then kindly do  |                |               |              |            |
# | so before the   |                |               |              |            |
# | deadline.       |                |               |              |            |
# | #Summer         |                |               |              |            |
# | #Research       |                |               |              |            |
# | #Internship     |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @IIITDelhi      | Mon Mar 18     | 4             | 4            | 1          |
# | invites         | 06:42:56 +0000 |               |              |            |
# | application     | 2019           |               |              |            |
# | from Foreign Na |                |               |              |            |
# | tionals/PIOs/NR |                |               |              |            |
# | Is/OCIs for     |                |               |              |            |
# | admission to    |                |               |              |            |
# | its https://t.c |                |               |              |            |
# | o/u6kIuhIrGM    |                |               |              |            |
# | and https://t.c |                |               |              |            |
# | o/Q0ibR1xaDl    |                |               |              |            |
# | Programs        |                |               |              |            |
# | through IIIT-   |                |               |              |            |
# | Delhi admission |                |               |              |            |
# | process for AY  |                |               |              |            |
# | 2019-20. Visit  |                |               |              |            |
# | Website for     |                |               |              |            |
# | more            |                |               |              |            |
# | information : h |                |               |              |            |
# | ttps://t.co/CGW |                |               |              |            |
# | qrughDw https:/ |                |               |              |            |
# | /t.co/c2o3593db |                |               |              |            |
# | R               |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | One more week   | Sun Mar 24     | 4             | 0            | None       |
# | is left to      | 11:34:27 +0000 |               |              |            |
# | submit the      | 2019           |               |              |            |
# | workshop        |                |               |              |            |
# | proposal to     |                |               |              |            |
# | @IEEEBigMM19.   |                |               |              |            |
# | Looking forward |                |               |              |            |
# | to your         |                |               |              |            |
# | submission. For |                |               |              |            |
# | any query,      |                |               |              |            |
# | contact         |                |               |              |            |
# | workshop co-    |                |               |              |            |
# | chair Dr.       |                |               |              |            |
# | Chiranjoy       |                |               |              |            |
# | Chattopadhyay   |                |               |              |            |
# | @cchatto or TPC |                |               |              |            |
# | co-chair        |                |               |              |            |
# | @RatnRajiv      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We are honored  | Sat Mar 23     | 6             | 5            | None       |
# | to have Dr.     | 05:17:50 +0000 |               |              |            |
# | Chang Wen Chen  | 2019           |               |              |            |
# | (Chinese        |                |               |              |            |
# | University Hong |                |               |              |            |
# | Kong            |                |               |              |            |
# | @CUHKofficial ) |                |               |              |            |
# | and Dr. Roger   |                |               |              |            |
# | Zimmermann      |                |               |              |            |
# | (National       |                |               |              |            |
# | University      |                |               |              |            |
# | Singapore       |                |               |              |            |
# | @NUSingapore )  |                |               |              |            |
# | as our General  |                |               |              |            |
# | co-chairs.      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Distinguished   | Sun Mar 24     | 13            | 3            | None       |
# | researchers Dr. | 05:58:27 +0000 |               |              |            |
# | Rajiv Ratn Shah | 2019           |               |              |            |
# | @RatnRajiv      |                |               |              |            |
# | (@IIITDelhi ,   |                |               |              |            |
# | @midasIIITD ),  |                |               |              |            |
# | Dr. Jianquan    |                |               |              |            |
# | Liu (NEC Japan) |                |               |              |            |
# | and Dr. Vivek   |                |               |              |            |
# | Singh (Rutgers  |                |               |              |            |
# | University      |                |               |              |            |
# | @RutgersU )     |                |               |              |            |
# | will be our     |                |               |              |            |
# | technical       |                |               |              |            |
# | program co-     |                |               |              |            |
# | chairs.         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @IEEEBigMM19 is | Wed Mar 20     | 1             | 1            | None       |
# | also available  | 08:19:24 +0000 |               |              |            |
# | on Facebook     | 2019           |               |              |            |
# | now.            |                |               |              |            |
# | LIKE its        |                |               |              |            |
# | Facebook page h |                |               |              |            |
# | ttps://t.co/B3Q |                |               |              |            |
# | 0zmmzXb  to get |                |               |              |            |
# | the regular     |                |               |              |            |
# | updates.        |                |               |              |            |
# | Check more      |                |               |              |            |
# | details at http |                |               |              |            |
# | s://t.co/w9Zymo |                |               |              |            |
# | Pisk            |                |               |              |            |
# |                 |                |               |              |            |
# | #IEEE #BigMM19  |                |               |              |            |
# | #Big            |                |               |              |            |
# | #Multimedia     |                |               |              |            |
# | #Singapore      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | BigMM 2019 :    | Tue Mar 19     | 6             | 5            | None       |
# | IEEE BigMM 2019 | 18:15:01 +0000 |               |              |            |
# | – Call for      | 2019           |               |              |            |
# | Workshop        |                |               |              |            |
# | Proposals       |                |               |              |            |
# |                 |                |               |              |            |
# | https://t.co/I4 |                |               |              |            |
# | vqf8FE6K …      |                |               |              |            |
# | When: Sep 11,   |                |               |              |            |
# | 2019 - Sep 13,  |                |               |              |            |
# | 2019            |                |               |              |            |
# | Where:          |                |               |              |            |
# | Singapore       |                |               |              |            |
# | Submission      |                |               |              |            |
# | Deadline: Apr   |                |               |              |            |
# | 1, 2019         |                |               |              |            |
# | Notification    |                |               |              |            |
# | Due: Apr 10,    |                |               |              |            |
# | 2019            |                |               |              |            |
# |                 |                |               |              |            |
# | #IEEE #BigData  |                |               |              |            |
# | #Singapore      |                |               |              |            |
# | #Multimedia     |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | BigMM 2019 :    | Mon Mar 18     | 6             | 3            | None       |
# | IEEE BigMM 2019 | 02:27:47 +0000 |               |              |            |
# | – Call for      | 2019           |               |              |            |
# | Workshop        |                |               |              |            |
# | Proposals       |                |               |              |            |
# |                 |                |               |              |            |
# | https://t.co/oU |                |               |              |            |
# | q2G0UgKN        |                |               |              |            |
# |                 |                |               |              |            |
# | When: Sep 11,   |                |               |              |            |
# | 2019 - Sep 13,  |                |               |              |            |
# | 2019            |                |               |              |            |
# | Where:          |                |               |              |            |
# | Singapore       |                |               |              |            |
# | Submission      |                |               |              |            |
# | Deadline: Apr   |                |               |              |            |
# | 1, 2019         |                |               |              |            |
# | Notification    |                |               |              |            |
# | Due: Apr 10,    |                |               |              |            |
# | 2019            |                |               |              |            |
# |                 |                |               |              |            |
# | #IEEE #BigMM    |                |               |              |            |
# | #Workshop       |                |               |              |            |
# | #Proposal       |                |               |              |            |
# | #Singapore      |                |               |              |            |
# | #Multimedia     |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Congratulations | Sun Mar 17     | 15            | 4            | None       |
# | @midasIIITD     | 14:22:04 +0000 |               |              |            |
# | team, Rohan,    | 2019           |               |              |            |
# | Pradyumn,       |                |               |              |            |
# | Ramit,          |                |               |              |            |
# | @debanjanbhucs, |                |               |              |            |
# | @MADAIguy and   |                |               |              |            |
# | @RatnRajiv for  |                |               |              |            |
# | getting their   |                |               |              |            |
# | paper titled,   |                |               |              |            |
# | "SNAP-BATNET:   |                |               |              |            |
# | Cascading       |                |               |              |            |
# | Author          |                |               |              |            |
# | Profiling and   |                |               |              |            |
# | Social Network  |                |               |              |            |
# | Graphs for      |                |               |              |            |
# | Suicide         |                |               |              |            |
# | Ideation        |                |               |              |            |
# | Detection on    |                |               |              |            |
# | Social Media",  |                |               |              |            |
# | accepted at     |                |               |              |            |
# | @NAACLHLT SRW.  |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We have emailed | Sat Mar 16     | 7             | 0            | None       |
# | the task        | 14:06:56 +0000 |               |              |            |
# | details to all  | 2019           |               |              |            |
# | shortlisted     |                |               |              |            |
# | candidates for  |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# | internship.     |                |               |              |            |
# | Kindly check    |                |               |              |            |
# | the same.       |                |               |              |            |
# |                 |                |               |              |            |
# | If you are one  |                |               |              |            |
# | of the          |                |               |              |            |
# | shortlisted     |                |               |              |            |
# | candidates and  |                |               |              |            |
# | have not        |                |               |              |            |
# | received the    |                |               |              |            |
# | email then      |                |               |              |            |
# | check your SPAM |                |               |              |            |
# | first before    |                |               |              |            |
# | approaching.    |                |               |              |            |
# |                 |                |               |              |            |
# | #MIDAS #Summer  |                |               |              |            |
# | #Research       |                |               |              |            |
# | #Internship     |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | IEEE BigMM 2019 | Sat Mar 16     | 1             | 1            | None       |
# | - Call for      | 09:20:29 +0000 |               |              |            |
# | Workshop        | 2019           |               |              |            |
# | Proposals.      |                |               |              |            |
# |                 |                |               |              |            |
# | Contact         |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# | @RatnRajiv      |                |               |              |            |
# | @debanjanbhucs  |                |               |              |            |
# | if you have any |                |               |              |            |
# | query.          |                |               |              |            |
# |                 |                |               |              |            |
# | Deadlines:      |                |               |              |            |
# | - Proposals     |                |               |              |            |
# | due: April 1,   |                |               |              |            |
# | 2019            |                |               |              |            |
# | - Acceptance    |                |               |              |            |
# | notification:   |                |               |              |            |
# | April 10, 2019  |                |               |              |            |
# |                 |                |               |              |            |
# | Further         |                |               |              |            |
# | information:    |                |               |              |            |
# | - Webpage: http |                |               |              |            |
# | s://t.co/5XX5Wy |                |               |              |            |
# | xp5T            |                |               |              |            |
# |                 |                |               |              |            |
# | #IEEE #BigMM19  |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Congratulations | Sat Mar 16     | 7             | 2            | None       |
# | ! Arijit,       | 09:14:58 +0000 |               |              |            |
# | Ramit,          | 2019           |               |              |            |
# | @debanjanbhucs  |                |               |              |            |
# | @RatnRajiv for  |                |               |              |            |
# | your @NAACLHLT  |                |               |              |            |
# | @naacl SRW 2019 |                |               |              |            |
# | paper, "Speak   |                |               |              |            |
# | Up, Fight Back! |                |               |              |            |
# | Detection of    |                |               |              |            |
# | Social Media    |                |               |              |            |
# | Disclosures of  |                |               |              |            |
# | Sexual          |                |               |              |            |
# | Harassment".    |                |               |              |            |
# |                 |                |               |              |            |
# | Check more      |                |               |              |            |
# | details at http |                |               |              |            |
# | s://t.co/i6eAHg |                |               |              |            |
# | 7gcN            |                |               |              |            |
# |                 |                |               |              |            |
# | #MeToo #Student |                |               |              |            |
# | #Research       |                |               |              |            |
# | #Paper #NAACL   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We will be      | Sat Mar 16     | 7             | 2            | None       |
# | releasing a     | 05:13:14 +0000 |               |              |            |
# | very            | 2019           |               |              |            |
# | interesting     |                |               |              |            |
# | task to         |                |               |              |            |
# | shortlisted     |                |               |              |            |
# | candidates for  |                |               |              |            |
# | the internship  |                |               |              |            |
# | at @midasIIITD  |                |               |              |            |
# | today. You will |                |               |              |            |
# | be having 10    |                |               |              |            |
# | days to solve   |                |               |              |            |
# | the same. You   |                |               |              |            |
# | will get a      |                |               |              |            |
# | detailed email  |                |               |              |            |
# | on the task and |                |               |              |            |
# | submission      |                |               |              |            |
# | instruction     |                |               |              |            |
# | today. Looking  |                |               |              |            |
# | forward to your |                |               |              |            |
# | out of box      |                |               |              |            |
# | solution.       |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Last day to     | Wed Mar 13     | 6             | 2            | 1          |
# | register for #P | 13:16:43 +0000 |               |              |            |
# | ortfolioCreatio | 2019           |               |              |            |
# | ninDesign       |                |               |              |            |
# | Workshop        |                |               |              |            |
# | Indraprastha    |                |               |              |            |
# | Institute of    |                |               |              |            |
# | Information     |                |               |              |            |
# | Technology,     |                |               |              |            |
# | Delhi on 15th   |                |               |              |            |
# | March by Ankur  |                |               |              |            |
# | Sardana         |                |               |              |            |
# | Register at - h |                |               |              |            |
# | ttps://t.co/LlO |                |               |              |            |
# | 29aGmaE         |                |               |              |            |
# | #HCDIIITD       |                |               |              |            |
# | #workshop https |                |               |              |            |
# | ://t.co/EWQ7fuG |                |               |              |            |
# | NDD             |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @ACMMM19 @sigmm | Wed Mar 13     | 1             | 0            | 1          |
# | @TheOfficialACM | 04:11:24 +0000 |               |              |            |
# | @acmmmsys       | 2019           |               |              |            |
# | @ACMTVX         |                |               |              |            |
# | @ACMICMR        |                |               |              |            |
# | @euromm         |                |               |              |            |
# | @Benoit_Huet    |                |               |              |            |
# | @RatnRajiv      |                |               |              |            |
# | @kelkalot       |                |               |              |            |
# | We need to      |                |               |              |            |
# | clearly mention |                |               |              |            |
# | abstract and    |                |               |              |            |
# | final           |                |               |              |            |
# | submission      |                |               |              |            |
# | deadlines at ht |                |               |              |            |
# | tps://t.co/U7DT |                |               |              |            |
# | NNyw87          |                |               |              |            |
# |                 |                |               |              |            |
# | Currently, we   |                |               |              |            |
# | have just       |                |               |              |            |
# | mentioned 1st   |                |               |              |            |
# | April as the    |                |               |              |            |
# | regular paper   |                |               |              |            |
# | submission      |                |               |              |            |
# | deadline.       |                |               |              |            |
# | Kindly update.  |                |               |              |            |
# |                 |                |               |              |            |
# | #ACMMM19 #Nice  |                |               |              |            |
# | #Multimedia htt |                |               |              |            |
# | ps://t.co/ocOCr |                |               |              |            |
# | lFHLH           |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | The paper       | Tue Mar 12     | 14            | 13           | None       |
# | deadline is     | 10:19:41 +0000 |               |              |            |
# | approaching. 1  | 2019           |               |              |            |
# | April abstract  |                |               |              |            |
# | is due. Authors |                |               |              |            |
# | will have until |                |               |              |            |
# | 8 April to      |                |               |              |            |
# | upload the      |                |               |              |            |
# | final PDF       |                |               |              |            |
# | version of      |                |               |              |            |
# | their paper     |                |               |              |            |
# | submission. For |                |               |              |            |
# | complete        |                |               |              |            |
# | submission      |                |               |              |            |
# | information,    |                |               |              |            |
# | see https://t.c |                |               |              |            |
# | o/zKyqPAxErM    |                |               |              |            |
# | @sigmm          |                |               |              |            |
# | @TheOfficialACM |                |               |              |            |
# | @acmmmsys       |                |               |              |            |
# | @ACMTVX         |                |               |              |            |
# | @ACMICMR        |                |               |              |            |
# | @euromm         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Bookmark this   | Tue Mar 12     | 236           | 67           | 1          |
# | amazing library | 17:15:52 +0000 |               |              |            |
# | of image        | 2019           |               |              |            |
# | augmentations 😵 |                |               |              |            |
# | by #Kaggle      |                |               |              |            |
# | Masters         |                |               |              |            |
# | @AlBuslaev      |                |               |              |            |
# | @creaf          |                |               |              |            |
# | @viglovikov and |                |               |              |            |
# | @cvtalks | http |                |               |              |            |
# | s://t.co/7hTShJ |                |               |              |            |
# | vbqZ #resources |                |               |              |            |
# | #machinelearnin |                |               |              |            |
# | g https://t.co/ |                |               |              |            |
# | QMOfNmU8dH      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Awesome members | Tue Mar 12     | 16            | 4            | 1          |
# | of our          | 14:37:55 +0000 |               |              |            |
# | @midasIIITD     | 2019           |               |              |            |
# | team who are    |                |               |              |            |
# | working on      |                |               |              |            |
# | Humonics        |                |               |              |            |
# | projects. Great |                |               |              |            |
# | to have you on  |                |               |              |            |
# | our team.       |                |               |              |            |
# |                 |                |               |              |            |
# | #team #research |                |               |              |            |
# | #AI #ML         |                |               |              |            |
# | #projects https |                |               |              |            |
# | ://t.co/lN7hItw |                |               |              |            |
# | PO9             |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @saanidhi       | Mon Mar 11     | 0             | 0            | None       |
# | @ACMMM19 Before | 14:58:30 +0000 |               |              |            |
# | Friday, 15th    | 2019           |               |              |            |
# | March.          |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We are glad to  | Mon Mar 11     | 4             | 0            | None       |
# | inform that     | 12:02:42 +0000 |               |              |            |
# | Adobe is        | 2019           |               |              |            |
# | launching       |                |               |              |            |
# | Women’s day     |                |               |              |            |
# | Tech-Challenge  |                |               |              |            |
# | to hire female  |                |               |              |            |
# | engineers from  |                |               |              |            |
# | 2019 Batch      |                |               |              |            |
# | under our       |                |               |              |            |
# | #SheCodes       |                |               |              |            |
# | initiative.     |                |               |              |            |
# | Please register |                |               |              |            |
# | here for        |                |               |              |            |
# | participating   |                |               |              |            |
# | in the          |                |               |              |            |
# | challenge at ht |                |               |              |            |
# | tps://t.co/DjkK |                |               |              |            |
# | CJHDBC          |                |               |              |            |
# |                 |                |               |              |            |
# | Check full      |                |               |              |            |
# | details at http |                |               |              |            |
# | s://t.co/5ArLu3 |                |               |              |            |
# | icva            |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We will email   | Mon Mar 11     | 3             | 0            | None       |
# | tasks to all    | 11:54:38 +0000 |               |              |            |
# | shortlisted     | 2019           |               |              |            |
# | candidates for  |                |               |              |            |
# | an internship   |                |               |              |            |
# | at @midasIIITD  |                |               |              |            |
# | by Friday, 15th |                |               |              |            |
# | March. If you   |                |               |              |            |
# | are shortlisted |                |               |              |            |
# | and did not     |                |               |              |            |
# | hear from us by |                |               |              |            |
# | that time then  |                |               |              |            |
# | kindly drop an  |                |               |              |            |
# | email to us.    |                |               |              |            |
# |                 |                |               |              |            |
# | Looking forward |                |               |              |            |
# | to working with |                |               |              |            |
# | you.            |                |               |              |            |
# |                 |                |               |              |            |
# | #research       |                |               |              |            |
# | #Internship #AI |                |               |              |            |
# | @ACMMM19        |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @ACMMM19        | Mon Mar 11     | 1             | 1            | None       |
# | @ACM_MM2018     | 06:22:12 +0000 |               |              |            |
# | @acmmm17 @sigmm | 2019           |               |              |            |
# | @ACM Less than  |                |               |              |            |
# | three weeks are |                |               |              |            |
# | left for        |                |               |              |            |
# | @ACMMM19        |                |               |              |            |
# | submission.     |                |               |              |            |
# | Looking forward |                |               |              |            |
# | to your         |                |               |              |            |
# | contribution to |                |               |              |            |
# | #ACMMM and see  |                |               |              |            |
# | you in Nice,    |                |               |              |            |
# | France.         |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# | @iiit_hyderabad |                |               |              |            |
# | @iitdelhi       |                |               |              |            |
# | @abhinavdhall   |                |               |              |            |
# | @iitmadras      |                |               |              |            |
# | @iiscbangalore  |                |               |              |            |
# | @IITKanpur      |                |               |              |            |
# | @iitbombay      |                |               |              |            |
# | @iitkharagpur   |                |               |              |            |
# | @IITJodhpur     |                |               |              |            |
# | @iitropar       |                |               |              |            |
# | @IIITDelhi      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Face            | Mon Mar 11     | 141           | 64           | 1          |
# | Recognition     | 06:00:10 +0000 |               |              |            |
# | using One-Shot  | 2019           |               |              |            |
# | Learning –      |                |               |              |            |
# | #DeepLearning   |                |               |              |            |
# | using DL        |                |               |              |            |
# | architecture    |                |               |              |            |
# | that works      |                |               |              |            |
# | great with one- |                |               |              |            |
# | shot learning   |                |               |              |            |
# | called Siamese  |                |               |              |            |
# | Network.        |                |               |              |            |
# | https://t.co/Z5 |                |               |              |            |
# | oH9vrCns https: |                |               |              |            |
# | //t.co/lAubt8vZ |                |               |              |            |
# | rM              |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @AvinashSwamina | Fri Mar 08     | 1             | 0            | None       |
# | 2 @IIITDelhi    | 13:22:07 +0000 |               |              |            |
# | No. They will   | 2019           |               |              |            |
# | be given tasks  |                |               |              |            |
# | along with      |                |               |              |            |
# | students who    |                |               |              |            |
# | will be         |                |               |              |            |
# | selected in the |                |               |              |            |
# | second round.   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | We are in the   | Fri Mar 08     | 8             | 4            | None       |
# | process of      | 13:15:34 +0000 |               |              |            |
# | finalizing the  | 2019           |               |              |            |
# | shortlisted     |                |               |              |            |
# | candidates for  |                |               |              |            |
# | internship at   |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# | which we have   |                |               |              |            |
# | received in the |                |               |              |            |
# | second round.   |                |               |              |            |
# | We will assign  |                |               |              |            |
# | tasks to all    |                |               |              |            |
# | shortlisted     |                |               |              |            |
# | candidates      |                |               |              |            |
# | around early    |                |               |              |            |
# | next week. We   |                |               |              |            |
# | are also        |                |               |              |            |
# | delaying the    |                |               |              |            |
# | task since DTU  |                |               |              |            |
# | has mid-sem     |                |               |              |            |
# | until 15 March. |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @ylecun         | Wed Mar 06     | 3             | 0            | None       |
# | @NilayShri      | 13:44:11 +0000 |               |              |            |
# | @the_dhumketu   | 2019           |               |              |            |
# | @debanjanbhucs  |                |               |              |            |
# | will it be      |                |               |              |            |
# | useful?         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Python Data     | Wed Mar 06     | 45            | 22           | 1          |
# | Science for     | 05:00:23 +0000 |               |              |            |
# | Beginners https | 2019           |               |              |            |
# | ://t.co/yRExdmd |                |               |              |            |
# | ZGh https://t.c |                |               |              |            |
# | o/vRqTRuayO3    |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Useful feature  | Wed Feb 27     | 127           | 35           | None       |
# | of our Python   | 18:37:37 +0000 |               |              |            |
# | stanfordnlp:    | 2019           |               |              |            |
# | get lemmas      |                |               |              |            |
# | &amp;           |                |               |              |            |
# | morphology in   |                |               |              |            |
# | many languages. |                |               |              |            |
# | Le ski de fond  |                |               |              |            |
# | touché→lemma    |                |               |              |            |
# | toucher feats G |                |               |              |            |
# | ender=Masc|Numb |                |               |              |            |
# | er=Sing|Tense=P |                |               |              |            |
# | ast|VerbForm=Pa |                |               |              |            |
# | rt              |                |               |              |            |
# | ei kerrottaisi→ |                |               |              |            |
# | lemma kertoa    |                |               |              |            |
# | feats Connegati |                |               |              |            |
# | ve=Yes|Mood=Cnd |                |               |              |            |
# | |VerbForm=Fin h |                |               |              |            |
# | ttps://t.co/p6M |                |               |              |            |
# | hHyHLC2         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @NilayShri      | Sun Mar 03     | 1             | 0            | None       |
# | @NilayShri,     | 17:09:48 +0000 |               |              |            |
# ...
# | workshops.  1)  |                |               |              |            |
# | Offensive       |                |               |              |            |
# | Tweets          |                |               |              |            |
# | Classification, |                |               |              |            |
# | 2)              |                |               |              |            |
# | Identification  |                |               |              |            |
# | of Blood        |                |               |              |            |
# | Donation        |                |               |              |            |
# | Request on      |                |               |              |            |
# | Twitter, 3)     |                |               |              |            |
# | Exploring and   |                |               |              |            |
# | Learning        |                |               |              |            |
# | Suicidal        |                |               |              |            |
# | Ideation        |                |               |              |            |
# | Connotations on |                |               |              |            |
# | Social Media,   |                |               |              |            |
# | 4) NMT for      |                |               |              |            |
# | English-Tamil   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Auto-Keras, or  | Wed Sep 05     | 31            | 11           | None       |
# | How You can     | 18:01:17 +0000 |               |              |            |
# | Create a        | 2018           |               |              |            |
# | #DeepLearning   |                |               |              |            |
# | Model in 4      |                |               |              |            |
# | Lines of Code   |                |               |              |            |
# | #KDN https://t. |                |               |              |            |
# | co/A1FgKE0ZKA   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Big Change:     | Wed Sep 05     | 0             | 1            | None       |
# | Diabetes        | 13:08:55 +0000 |               |              |            |
# | patients are    | 2018           |               |              |            |
# | looking for     |                |               |              |            |
# | diabetes        |                |               |              |            |
# | management      |                |               |              |            |
# | systems.        |                |               |              |            |
# | Manufacturers   |                |               |              |            |
# | of continuous   |                |               |              |            |
# | glucose         |                |               |              |            |
# | monitoring      |                |               |              |            |
# | devices seem to |                |               |              |            |
# | be getting the  |                |               |              |            |
# | message.  This  |                |               |              |            |
# | will be a major |                |               |              |            |
# | change for      |                |               |              |            |
# | diabetes        |                |               |              |            |
# | sufferers.      |                |               |              |            |
# | #FutureHealth   |                |               |              |            |
# | #PHN https://t. |                |               |              |            |
# | co/qqoQk0BMSH   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | #NIPS2018 The   | Tue Sep 04     | 1085          | 688          | None       |
# | main conference | 16:17:58 +0000 |               |              |            |
# | sold out in 11  | 2018           |               |              |            |
# | minutes 38      |                |               |              |            |
# | seconds         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Paper titled,   | Tue Sep 04     | 5             | 1            | None       |
# | "Exploring and  | 16:19:56 +0000 |               |              |            |
# | Learning        | 2018           |               |              |            |
# | Suicidal        |                |               |              |            |
# | Ideation        |                |               |              |            |
# | Connotations on |                |               |              |            |
# | Social Media    |                |               |              |            |
# | with Deep       |                |               |              |            |
# | Learning", got  |                |               |              |            |
# | accepted to     |                |               |              |            |
# | WASSA at        |                |               |              |            |
# | @emnlp2018      |                |               |              |            |
# | Congratulations |                |               |              |            |
# | authors, Ramit  |                |               |              |            |
# | Sawhney, Prachi |                |               |              |            |
# | Manchanda,      |                |               |              |            |
# | @punnibhai,     |                |               |              |            |
# | @RatnRajiv, Raj |                |               |              |            |
# | Singh for great |                |               |              |            |
# | work.           |                |               |              |            |
# | #MIDAS #EMNLP   |                |               |              |            |
# | #WASSA #IIITD   |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | The fourth      | Tue Sep 04     | 3             | 1            | None       |
# | paper (and 3rd  | 16:16:37 +0000 |               |              |            |
# | of @punnibhai)  | 2018           |               |              |            |
# | got accepted    |                |               |              |            |
# | into @emnlp2018 |                |               |              |            |
# | workshops.      |                |               |              |            |
# | Congratulations |                |               |              |            |
# | Team            |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# |                 |                |               |              |            |
# | #MIDAS #EMNLP   |                |               |              |            |
# | #Achievment     |                |               |              |            |
# | #Success #IIITD |                |               |              |            |
# | #WASSA          |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Calls for       | Tue Sep 04     | 45            | 34           | None       |
# | papers for      | 14:40:08 +0000 |               |              |            |
# | #naacl2019 are  | 2018           |               |              |            |
# | up!             |                |               |              |            |
# | Research track: |                |               |              |            |
# | https://t.co/tv |                |               |              |            |
# | FJx6P3Zs        |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Text            | Mon Sep 03     | 63            | 28           | 1          |
# | Classification  | 22:57:01 +0000 |               |              |            |
# | &amp;           | 2018           |               |              |            |
# | Embeddings      |                |               |              |            |
# | Visualization   |                |               |              |            |
# | Using LSTMs,    |                |               |              |            |
# | CNNs, and Pre-  |                |               |              |            |
# | trained Word    |                |               |              |            |
# | Vectors https:/ |                |               |              |            |
# | /t.co/ir0jssoMk |                |               |              |            |
# | h https://t.co/ |                |               |              |            |
# | vXqRTUUATO      |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @mr2amc         | Mon Sep 03     | 2             | 3            | None       |
# | challenge on    | 13:14:34 +0000 |               |              |            |
# | "Multimodal     | 2018           |               |              |            |
# | Sentiment       |                |               |              |            |
# | Analysis        |                |               |              |            |
# | Challenge" is   |                |               |              |            |
# | up now. You may |                |               |              |            |
# | visit the       |                |               |              |            |
# | following link  |                |               |              |            |
# | for more        |                |               |              |            |
# | details:        |                |               |              |            |
# |                 |                |               |              |            |
# | https://t.co/1T |                |               |              |            |
# | oO2qBPV9        |                |               |              |            |
# |                 |                |               |              |            |
# | Please share    |                |               |              |            |
# | the challenge   |                |               |              |            |
# | @midasIIITD     |                |               |              |            |
# | @soujanyaporia  |                |               |              |            |
# | @debanjanbhucs  |                |               |              |            |
# |                 |                |               |              |            |
# | #MIDAS #MR2AMC  |                |               |              |            |
# | #ISM #IEEE      |                |               |              |            |
# | #Challenge      |                |               |              |            |
# | #Sentiment      |                |               |              |            |
# | #Emotion        |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | Submitting to   | Tue Aug 28     | 36            | 33           | None       |
# | The Web         | 13:19:33 +0000 |               |              |            |
# | Conference 2019 | 2018           |               |              |            |
# | (WWW 2019) in   |                |               |              |            |
# | San Francisco?  |                |               |              |            |
# | Abstracts due   |                |               |              |            |
# | Oct. 29, full   |                |               |              |            |
# | papers Nov. 5!  |                |               |              |            |
# | Full CFP: https |                |               |              |            |
# | ://t.co/dgESpey |                |               |              |            |
# | 5IY             |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | First Steps of  | Sat Sep 01     | 62            | 25           | 1          |
# | Learning Deep   | 14:42:04 +0000 |               |              |            |
# | Learning: Image | 2018           |               |              |            |
# | Classification  |                |               |              |            |
# | in Keras https: |                |               |              |            |
# | //t.co/eroBz5Eh |                |               |              |            |
# | S8 https://t.co |                |               |              |            |
# | /5CN1eQHbTP     |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | @debanjanbhucs  | Sat Sep 01     | 1             | 0            | None       |
# | @debanjanbhucs, | 03:09:52 +0000 |               |              |            |
# | thanks for      | 2018           |               |              |            |
# | sharing.        |                |               |              |            |
# | @the_dhumketu   |                |               |              |            |
# | this will be    |                |               |              |            |
# | useful.         |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
# | GREAT 9-page    | Fri Aug 31     | 13            | 9            | 2          |
# | reference in    | 13:09:24 +0000 |               |              |            |
# | basic           | 2018           |               |              |            |
# | #datascience.   |                |               |              |            |
# | Here: https://t |                |               |              |            |
# | .co/g3EHvtd65h  |                |               |              |            |
# |                 |                |               |              |            |
# | Covers basic    |                |               |              |            |
# | concepts in     |                |               |              |            |
# | probability,    |                |               |              |            |
# | #statistics, #s |                |               |              |            |
# | tatisticallearn |                |               |              |            |
# | ing, #machinele |                |               |              |            |
# | arning,         |                |               |              |            |
# | #bigdata        |                |               |              |            |
# | frameworks and  |                |               |              |            |
# | #SQL            |                |               |              |            |
# |                 |                |               |              |            |
# | #ML #AI #DL     |                |               |              |            |
# | #analytics      |                |               |              |            |
# | @rstats         |                |               |              |            |
# | #datascientist  |                |               |              |            |
# | @kdnuggets http |                |               |              |            |
# | s://t.co/00eXY6 |                |               |              |            |
# | kyQS            |                |               |              |            |
# +-----------------+----------------+---------------+--------------+------------+
